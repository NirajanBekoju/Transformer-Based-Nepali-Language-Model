# %%
import os
from utils import getTokenizer

# %%
file_path = 'data/preprocessed_ne_dedup.txt'
print(f"Reading file  : {file_path}")
with open(file_path, 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
# Reading file  : data/preprocessed_ne_dedup.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 file_path = 'data/preprocessed_ne_dedup.txt'
#       2 print(f"Reading file  : {file_path}")
# ----> 3 with open(file_path, 'r', encoding='utf-8') as f:
#       4     text = f.read()
#
# File ~/miniconda3/envs/cslr/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/preprocessed_ne_dedup.txt'

# %%
train_split = 300_000

train_iter = text.split('\n')[:train_split]
test_iter = text.split('\n')[train_split:]

print(len(train_iter), len(test_iter))

# %%
tokenizer, vocab = getTokenizer()
print(len(vocab))
# Out:
# 60507

# %%
vocab.vocab.itos_
# Out:
# ['<unk>',
#  '।',
#  ',',
#  '<num>',
#  'र',
#  'छ',
#  'पनि',
#  'भएको',
#  'छन्',
#  'हो',
#  'लागि',
#  'गरेको',
#  'गर्न',
#  'भने',
#  'गर्ने',
#  'तथा',
#  'थियो',
#  'यो',
#  'नै',
#  'एक',
#  'तर',
#  'हुने',
#  'रहेको',
#  'नेपाल',
#  'गरेका',
#  'थिए',
#  'नेपाली',
#  'गरिएको',
#  'भन्ने',
#  'काम',
#  'उनले',
#  'गरी',
#  'हुन्छ',
#  'को',
#  'आफ्नो',
#  'मा',
#  'गर्दै',
#  'त',
#  'हुन',
#  'केही',
#  'छैन',
#  'भएका',
#  '?',
#  'हजार',
#  'दिन',
#  'कुनै',
#  'मात्र',
#  'कुरा',
#  'सबै',
#  'रुपमा',
#  'वा',
#  'यस',
#  'कारण',
#  'समेत',
#  'दुई',
#  'धेरै',
#  'काठमाडौं',
#  'अहिले',
#  'हुन्',
#  'नयाँ',
#  'गरेर',
#  'जानकारी',
#  'अध्यक्ष',
#  'त्यो',
#  'सरकारले',
#  'बताए',
#  'निर्माण',
#  'अनुसार',
#  'स्थानीय',
#  'आएको',
#  'लाख',
#  'विकास',
#  'भए',
#  'प्रमुख',
#  'भयो',
#  'सय',
#  'विभिन्न',
#  'म',
#  'जिल्ला',
#  'बढी',
#  'एउटा',
#  'वर्ष',
#  'पहिलो',
#  'के',
#  'गरे',
#  'गर्दा',
#  'आर्थिक',
#  'प्रहरी',
#  'रहेका',
#  'रूपमा',
#  'उक्त',
#  'आज',
#  'हामी',
#  'राष्ट्रिय',
#  'भन्दै',
#  'भनेर',
#  'उनको',
#  'क्षेत्रमा',
#  'समय',
#  'प्रदेश',
#  'उनी',
#  'कार्यक्रम',
#  'भन्दा',
#  'अन्य',
#  'अब',
#  'गते',
#  'प्रधानमन्त्री',
#  'नेपालको',
#  'दिने',
#  'सेवा',
#  'प्रयोग',
#  'जना',
#  'हाम्रो',
#  'समस्या',
#  'तीन',
#  'व्यवस्था',
#  'सार्वजनिक',
#  'राजनीतिक',
#  'गर्नु',
#  'कि',
#  'सहयोग',
#  'होइन',
#  'दिएको',
#  'करोड',
#  'मैले',
#  'मेरो',
#  'सरकार',
#  'नेपालमा',
#  'पर्ने',
#  'प्राप्त',
#  'यस्तो',
#  'सम्पन्न',
#  'कार्यक्रममा',
#  'सुरु',
#  'ठूलो',
#  'देखि',
#  'सो',
#  'हामीले',
#  'घर',
#  'आयोजना',
#  'पार्टी',
#  'अघि',
#  'प्रतिशत',
#  'कार्यालय',
#  'जनाएको',
#  'मात्रै',
#  'राम्रो',
#  'साथै',
#  'आएका',
#  'वटा',
#  'क्रममा',
#  'सामाजिक',
#  'अनि',
#  'निर्णय',
#  'आवश्यक',
#  'निर्वाचन',
#  'यी',
#  'स्वास्थ्य',
#  'भएर',
#  'पछि',
#  'लागेको',
#  'का',
#  'महिला',
#  'अवस्थामा',
#  'डा',
#  'यसको',
#  'अवस्था',
#  'गएको',
#  'बनाउन',
#  'विषयमा',
#  'अर्को',
#  'रुपैयाँ',
#  'मलाई',
#  'साथ',
#  'नेता',
#  'सन्',
#  'परेको',
#  'सञ्चालन',
#  'काठमाडौँ',
#  'माग',
#  'जारी',
#  'उहाँले',
#  'पटक',
#  'बनाउने',
#  'दिए',
#  'ती',
#  'क्षेत्र',
#  'हुनेछ',
#  'गत',
#  'बेला',
#  'सडक',
#  'कम',
#  'सदस्य',
#  'सकिन्छ',
#  'अगाडि',
#  'निकै',
#  'समयमा',
#  'भारतीय',
#  'थप',
#  'भएकाले',
#  'प्रहरीले',
#  'तयार',
#  'हुँदा',
#  'रकम',
#  'आउने',
#  'दोस्रो',
#  'योजना',
#  'सक्छ',
#  'संविधान',
#  'उत्पादन',
#  'रु',
#  'शिक्षा',
#  'त्यसैले',
#  'उल्लेख',
#  'भएपछि',
#  'नाम',
#  'बताउनुभयो',
#  'भइरहेको',
#  'सफल',
#  'जस्तो',
#  'ले',
#  'नगरपालिका',
#  'जाने',
#  'हुँदै',
#  'सक्ने',
#  'लिएर',
#  'चार',
#  'पाँच',
#  'सरकारी',
#  'मृत्यु',
#  'लामो',
#  'मुख्य',
#  'जुन',
#  'भनेको',
#  'विशेष',
#  'बताएका',
#  'सबैभन्दा',
#  'पक्राउ',
#  'प्रदान',
#  'वडा',
#  'कसरी',
#  'देखिन्छ',
#  'आधारमा',
#  'सरकारको',
#  'गरिने',
#  'हरेक',
#  'गर्नुपर्ने',
#  'खर्च',
#  'लगानी',
#  'न',
#  'त्यस्तै',
#  'त्यसको',
#  'मन्त्री',
#  'कार्य',
#  'एवं',
#  'यही',
#  'दिएका',
#  'बारेमा',
#  'घोषणा',
#  'पुगेको',
#  'छु',
#  'मन',
#  'आफ्ना',
#  'उच्च',
#  'बनेको',
#  'पूरा',
#  'होला',
#  'माओवादी',
#  'नेपालले',
#  'उनलाई',
#  'करिब',
#  'यसले',
#  'थाहा',
#  'यहाँ',
#  'किन',
#  'नं',
#  'यस्तै',
#  'अन्तर्राष्ट्रिय',
#  'त्यही',
#  'देश',
#  'पछिल्लो',
#  'आफ्नै',
#  'यस्ता',
#  'छलफल',
#  'सम्म',
#  'गर्छ',
#  'देखिएको',
#  'कृषि',
#  'अर्ब',
#  'तयारी',
#  'आगामी',
#  'सुरक्षा',
#  'उपलब्ध',
#  'पानी',
#  'नेपालका',
#  'अधिकार',
#  'खेलमा',
#  'स्थापना',
#  'वर्षको',
#  'हुँदैन',
#  'केन्द्रीय',
#  'पर्छ',
#  'गीत',
#  'समिति',
#  'नीति',
#  'पत्रकार',
#  'गाउँपालिका',
#  'अझै',
#  'भारत',
#  'नभएको',
#  'पाउने',
#  'खेल',
#  'छन',
#  'अध्ययन',
#  'पैसा',
#  'लिन',
#  'अन्तिम',
#  'विषय',
#  'नम्बर',
#  'सहभागी',
#  'परेका',
#  'सूचना',
#  'बाट',
#  'स्थानमा',
#  'बजारमा',
#  'दुवै',
#  'प्रस्तुत',
#  'बढेको',
#  'राष्ट्रपति',
#  'छौं',
#  'छैनन्',
#  'व्यवस्थापन',
#  'घरमा',
#  'युवा',
#  'ठाउँमा',
#  'जनताको',
#  'हाल',
#  'शुरु',
#  'यसरी',
#  'केन्द्र',
#  'थिएन',
#  'हुन्छन्',
#  'हुनु',
#  'अनुसन्धान',
#  'मूल्य',
#  'बजेट',
#  'नेकपा',
#  'गरिरहेको',
#  'बन्द',
#  'उपचार',
#  'परिवर्तन',
#  'विश्वास',
#  'बाँकी',
#  'दर्ता',
#  'गठन',
#  'कति',
#  'संयुक्त',
#  'त्यसपछि',
#  'जिल्लामा',
#  'यसलाई',
#  'पोखरा',
#  'नागरिक',
#  'चलचित्र',
#  'बाहिर',
#  'त्यहाँ',
#  'जीवन',
#  'आग्रह',
#  'सामान्य',
#  'उद्योग',
#  'जस्तै',
#  'बजार',
#  'बिहान',
#  'पूर्व',
#  'एमाले',
#  'राष्ट्र',
#  'उनका',
#  'जस्ता',
#  'सम्बन्ध',
#  'गर्छन्',
#  'त्यस',
#  'विश्व',
#  'नाममा',
#  'ध्यान',
#  'देशको',
#  'कायम',
#  'गरि',
#  'व्यक्त',
#  'नहुने',
#  'समाज',
#  'शर्मा',
#  'भूमिका',
#  'भन्छन्',
#  'फरक',
#  'दिनुभयो',
#  'पर्यटन',
#  'गरिरहेका',
#  'अमेरिकी',
#  'भनाइ',
#  'गरेपछि',
#  'गर्नुभएको',
#  'यसमा',
#  'सकेको',
#  'सकिने',
#  'क्षेत्रको',
#  'पहिले',
#  'कात्तिक',
#  'निर्देशन',
#  'वितरण',
#  'लगायतका',
#  'सम्मान',
#  'बस्ने',
#  'बाटो',
#  'गरिन्छ',
#  'कर',
#  'प्रवेश',
#  'महिना',
#  'फेरि',
#  'असार',
#  'लिएको',
#  'समाचार',
#  'प्रस्ताव',
#  'रहने',
#  'भदौ',
#  'जसले',
#  'महत्वपूर्ण',
#  'सम्बन्धित',
#  'संघीय',
#  'कर्मचारी',
#  'गर्नुपर्छ',
#  'सहित',
#  'थालेको',
#  'बनाएको',
#  'भन्नुभयो',
#  'प्रयास',
#  'यसअघि',
#  'देशमा',
#  'हत्या',
#  'नेतृत्व',
#  'अधिकारी',
#  'लाग्ने',
#  'लाग्छ',
#  'सहमति',
#  'प्रक्रिया',
#  'असोज',
#  'अवसरमा',
#  'लाई',
#  'मत',
#  'भई',
#  'सम्भावना',
#  'घटना',
#  'सम्पूर्ण',
#  'कार्यान्वयन',
#  'निजी',
#  'कतिपय',
#  'औं',
#  'भारतको',
#  'बताउँछन्',
#  'सहज',
#  'सम्झौता',
#  'आरोप',
#  'लिने',
#  'थापा',
#  'अस्पताल',
#  'अवसर',
#  'गराउने',
#  'राख्ने',
#  'संस्था',
#  'हात',
#  'तेस्रो',
#  'बन्न',
#  'जान',
#  'संख्या',
#  'सोही',
#  'ओलीले',
#  'सचिव',
#  'श्रेष्ठ',
#  'बैंक',
#  'संघ',
#  'व्यक्ति',
#  'बनाएर',
#  'गोल',
#  'विद्यालय',
#  'आफू',
#  'रहेछ',
#  'जिल्लाको',
#  'ऐन',
#  'जनाको',
#  'आफूलाई',
#  'प्रश्न',
#  'कम्पनीले',
#  'यसका',
#  'अरु',
#  'दिनमा',
#  'फिल्म',
#  'पाएको',
#  'केपी',
#  'केहि',
#  'बैठक',
#  'उसले',
#  'विद्यार्थी',
#  'प्रत्येक',
#  'वातावरण',
#  'शान्ति',
#  'समितिले',
#  'पार्टीको',
#  'सोमबार',
#  'गर्नुभयो',
#  'यदि',
#  'राखेर',
#  'त्यस्तो',
#  'वर्षीय',
#  'गराउन',
#  'अझ',
#  'शुक्रबार',
#  'त्यसलाई',
#  'कसैले',
#  'मुद्दा',
#  'साउन',
#  'दाबी',
#  'शक्ति',
#  'आजको',
#  'लगायत',
#  'पूर्ण',
#  'सात',
#  'निर्देशक',
#  'हामीलाई',
#  'सुधार',
#  'जति',
#  'दक्षिण',
#  'बुधबार',
#  'राज्य',
#  'दैनिक',
#  'बिक्री',
#  'गर्दछ',
#  'अधिकृत',
#  'बजे',
#  'भइसकेको',
#  'समितिको',
#  'बसेको',
#  'कम्पनी',
#  'जो',
#  'संरक्षण',
#  'सवारी',
#  'जोड',
#  'कांग्रेस',
#  'व्यापार',
#  'आउन',
#  'माथि',
#  'अर्थ',
#  'आफूले',
#  'वर्षमा',
#  'निर्वाचनमा',
#  'लक्ष्य',
#  'वृद्धि',
#  'भिडियो',
#  'आइतबार',
#  'सुविधा',
#  'गम्भीर',
#  'कहिले',
#  'विदेशी',
#  'क्षेत्रका',
#  'अफ',
#  'बैठकले',
#  'कारणले',
#  'लागी',
#  'जनता',
#  'दल',
#  'यति',
#  'शनिबार',
#  'अभियान',
#  'बैंकले',
#  'भित्र',
#  'स्पष्ट',
#  'राख्न',
#  'पाइन्छ',
#  'जिम्मेवारी',
#  'आन्तरिक',
#  'सम्बोधन',
#  'चर्चा',
#  'सालमा',
#  'आवश्यकता',
#  'थापाले',
#  'बन्ने',
#  'सम्बन्धी',
#  'उत्तर',
#  'अहिलेसम्म',
#  'समितिका',
#  'ज्यान',
#  'कानुन',
#  'भएन',
#  'छिन्',
#  'पुगेका',
#  'उत्कृष्ट',
#  'त्यसमा',
#  'जग्गा',
#  'चुनाव',
#  'समूह',
#  'संयोजक',
#  'मन्त्रालयले',
#  'आयोजित',
#  'एकता',
#  'कार्यक्रमको',
#  'पुग्ने',
#  'बैठकमा',
#  'बर्ष',
#  'भनी',
#  'पहिचान',
#  'या',
#  'हुनुपर्छ',
#  'विवरण',
#  'जरुरी',
#  'मानव',
#  'भन्न',
#  'तपाईं',
#  'पक्षमा',
#  'एउटै',
#  'आधार',
#  'मान्छे',
#  'स्थापित',
#  'मार्फत',
#  'ठूला',
#  'भाषा',
#  'देशका',
#  'घाइते',
#  'यात्रा',
#  'तहको',
#  'काममा',
#  'अन्तर्गत',
#  'जेठ',
#  'उसको',
#  'सम्बन्धमा',
#  'पराजित',
#  'गरेकी',
#  'ओली',
#  'चरणमा',
#  'कमजोर',
#  'राई',
#  'अमेरिका',
#  'नसकेको',
#  'लागू',
#  'आमा',
#  'थिइन्',
#  'राजधानी',
#  'कस्तो',
#  'भवन',
#  'मंगलबार',
#  'तहमा',
#  'कुन',
#  'सानो',
#  'विस्तार',
#  'नि',
#  'संशोधन',
#  'सिर्जना',
#  'अस्पतालमा',
#  'आन्दोलन',
#  'धार्मिक',
#  'श्रेष्ठले',
#  'अधिकांश',
#  'कारोबार',
#  'तत्कालीन',
#  'निर्वाचित',
#  'राखिएको',
#  'आदि',
#  'प्रदर्शन',
#  'यसै',
#  'क्षमता',
#  'प्राविधिक',
#  'चीन',
#  'राखेको',
#  'नियन्त्रण',
#  'प्रभावित',
#  'तत्काल',
#  'जब',
#  'भाग',
#  'पार्टीका',
#  'जनताले',
#  'वित्तीय',
#  'सांसद',
#  'रोग',
#  'गाउँ',
#  'जम्मा',
#  'खरिद',
#  'शेयर',
#  'अर्थात्',
#  'खबर',
#  'हाम्रा',
#  'प्रेम',
#  'टोली',
#  'गर्यो',
#  'स्थान',
#  'तर्फबाट',
#  'कोही',
#  'प्रकाशित',
#  'यातायात',
#  'चिनियाँ',
#  'संकलन',
#  'कार्यकारी',
#  'असर',
#  'विचार',
#  'समन्वय',
#  'समाधान',
#  'पुरा',
#  'फुटबल',
#  'स्थित',
#  'ल्याउन',
#  'दिइएको',
#  'भ्रमण',
#  'सरकारलाई',
#  'शाखा',
#  'नगर',
#  'लगाउने',
#  'उहाँको',
#  'सकारात्मक',
#  'भौतिक',
#  'संलग्न',
#  'दिएर',
#  'बताउँदै',
#  'बताइएको',
#  'उनीहरुले',
#  'नसक्ने',
#  'जे',
#  'अहिलेको',
#  'त्यति',
#  'उपाध्यक्ष',
#  'पुरस्कार',
#  'गलत',
#  'ल्याएको',
#  'विरोध',
#  'अनुभव',
#  'गुरुङ',
#  'प्रभावकारी',
#  'टोलीले',
#  'कुल',
#  'सुरक्षित',
#  'निम्ति',
#  'छौँ',
#  'गाडी',
#  'सञ्चालनमा',
#  'प्रभाव',
#  'नियमित',
#  'परिवार',
#  'सुझाव',
#  'मिति',
#  'माघ',
#  'जिल्लाका',
#  'बनेका',
#  'गएर',
#  'उम्मेदवार',
#  'ऋण',
#  'समाजमा',
#  'छोरा',
#  'सहभागिता',
#  'हुनुहुन्छ',
#  'अनुमान',
#  'भनिएको',
#  'थिएँ',
#  'आयोगले',
#  'शैक्षिक',
#  'भएपनि',
#  'बस',
#  'गयो',
#  'आयो',
#  'प्रशासन',
#  'बसेर',
#  'बिहीबार',
#  'सबैको',
#  'हेर्न',
#  'सहकारी',
#  'प्रतियोगितामा',
#  'पत्र',
#  'वैदेशिक',
#  'गुनासो',
#  'हुनुपर्ने',
#  'सबैलाई',
#  'वन',
#  'विकासका',
#  'बलियो',
#  'निरन्तर',
#  'सञ्चार',
#  'फिर्ता',
#  'विवाह',
#  'होस्',
#  'गरिएका',
#  'अन्त्य',
#  'कुरामा',
#  'सभापति',
#  'अधिकारीले',
#  'विदेश',
#  'बढ्दै',
#  'ल्याउने',
#  'प्रवक्ता',
#  'पूजा',
#  'खेलाडी',
#  'राति',
#  'चर्चित',
#  'फागुन',
#  'संस्कृति',
#  'राजा',
#  'लाग्यो',
#  'मंसिर',
#  'रासस',
#  'हुन्थ्यो',
#  'सक्रिय',
#  'उनीहरुको',
#  'योगदान',
#  'धारणा',
#  'कथा',
#  'सपना',
#  'पूर्वाधार',
#  'माया',
#  'कार्यालयले',
#  'स्रोत',
#  'जाँदा',
#  'हेर्दा',
#  'प्रतिनिधि',
#  'उद्घाटन',
#  'प्रतिवेदन',
#  'व्यवसायी',
#  'संचालन',
#  'शिक्षक',
#  'गएका',
#  'थालेका',
#  'पाएका',
#  'सभा',
#  'कार्यालयमा',
#  'आठ',
#  'पुरानो',
#  'वरिष्ठ',
#  'भएकोले',
#  'मध्ये',
#  'मुलुकको',
#  'निर्माणको',
#  'नेतृत्वको',
#  'सामुदायिक',
#  'राजनीति',
#  'गरियो',
#  'लोकतान्त्रिक',
#  'सबैले',
#  'प्रथम',
#  'गायक',
#  'नेतृत्वमा',
#  'मुलुक',
#  'पुनः',
#  'क्षति',
#  'क्रिकेट',
#  'प्रति',
#  'आएर',
#  'विद्युत्',
#  'भनेका',
#  'पारित',
#  'खान',
#  'स्वागत',
#  'कक्षा',
#  'मानिस',
#  'पारेको',
#  'दलका',
#  'कार्यरत',
#  'पाउन',
#  'त्यसैगरी',
#  'कम्पनीको',
#  'फोन',
#  'बहादुर',
#  'दिनु',
#  'वर्तमान',
#  'उनीहरु',
#  'प्रत्यक्ष',
#  'आम',
#  'ठाउँ',
#  'हासिल',
#  'कारबाही',
#  'मुलुकमा',
#  'सक्छन्',
#  'गर्नका',
#  'अभाव',
#  'वाणिज्य',
#  'जहाँ',
#  'सेयर',
#  'साँझ',
#  'तह',
#  'विवाद',
#  'संसदीय',
#  'भारतले',
#  'निश्चित',
#  'खाने',
#  'प्रणाली',
#  'पौडेल',
#  'छोरी',
#  'प्रतियोगिता',
#  'कम्युनिष्ट',
#  'संग',
#  'अनुगमन',
#  'मान्यता',
#  'मन्त्रालय',
#  'लागेका',
#  'सन्दर्भमा',
#  'मन्दिर',
#  'बढाउन',
#  'खुला',
#  'पर्दछ',
#  'उपयुक्त',
#  'साहित्य',
#  'वार्षिक',
#  'कहिल्यै',
#  'दुर्घटना',
#  'त्यसले',
#  'नभई',
#  'पौडेलले',
#  'पार्ने',
#  'विकासको',
#  'चितवन',
#  'दशमलव',
#  'प्रहरीको',
#  'लगाएर',
#  'शब्द',
#  'त्यसका',
#  'सांस्कृतिक',
#  'प्राकृतिक',
#  'आदेश',
#  'अघिल्लो',
#  'खाना',
#  'सीमा',
#  'तय',
#  'न्याय',
#  'लगाएको',
#  'वैशाख',
#  'धर्म',
#  'साना',
#  'मतदान',
#  'पक्ष',
#  'ऐतिहासिक',
#  'रन',
#  'बाध्य',
#  'बढ्ने',
#  'पहल',
#  'दिँदै',
#  'एकै',
#  'केन्द्रित',
#  'संरचना',
#  'कलाकार',
#  'सम्भव',
#  'अरू',
#  'राज्यको',
#  'उनीहरूले',
#  'उहाँ',
#  'भनिन्छ',
#  'हैन',
#  'सही',
#  'सक्दैन',
#  'गाउँमा',
#  'पुरुष',
#  'कतै',
#  'निर्माणका',
#  'हेर्ने',
#  'ए',
#  'स्वतन्त्र',
#  'मेडिकल',
#  'नियम',
#  'लिएका',
#  'प्रदेशको',
#  'उनीहरू',
#  'कहाँ',
#  'श्री',
#  'उचित',
#  'तामाङ',
#  'बढाउने',
#  'तालिम',
#  'थुप्रै',
#  'पार्न',
#  'लगाउन',
#  'आम्दानी',
#  'आयोजनामा',
#  'जनतालाई',
#  'उनीहरूको',
#  'बैंकको',
#  'प्रविधि',
#  'सम्मेलन',
#  'सुन',
#  'शुल्क',
#  'अनुरोध',
#  'मिटर',
#  'वर्षदेखि',
#  'आयात',
#  'व्यवसाय',
#  'विधेयक',
#  'स्थायी',
#  'फाइदा',
#  'पुल',
#  'जवाफ',
#  'एवम्',
#  'श्रम',
#  'भर्ना',
#  'सुन्दर',
#  'त्यस्ता',
#  'औषधि',
#  'सर्वोच्च',
#  'कार्तिक',
#  'निर्धारण',
#  'साझा',
#  'आधारित',
#  'गराएको',
#  ...]
